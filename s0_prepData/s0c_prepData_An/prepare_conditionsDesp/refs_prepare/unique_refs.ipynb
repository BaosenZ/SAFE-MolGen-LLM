# %%
import pandas as pd

# %%
file_path = "../../db_An_full.xlsx"
df = pd.read_excel(file_path, header=1)
df.head()
# Out:
#    Entry_ID  Extractants_count  \
# 0         0                  1
# 1         1                  1
# 2         2                  1
# 3         3                  1
# 4         4                  1
#
#                                               SMILES  Extractant_conc_M  \
# 0  CCCCN(CCCC)C(=O)COCC(=O)N(CC)CCN(CC)C(=O)COCC(...              0.008
# 1  CCCCN(CCCC)C(=O)COCC(=O)N(CC)CCN(CC)C(=O)COCC(...              0.008
# 2  CCCCN(CCCC)C(=O)COCC(=O)N(CC)CCN(CC)C(=O)COCC(...              0.008
# 3  CCCCN(CCCC)C(=O)COCC(=O)N(CC)CCN(CC)C(=O)COCC(...              0.008
# 4  CCCCN(CCCC)C(=O)COCC(=O)N(CC)CCN(CC)C(=O)COCC(...              0.008
#
#      Solvent_A Solvent_B  Volume_fraction_A  Volume_fraction_B   Metal  \
# 0  1-dodecanol       NaN                1.0                0.0  Th(IV)
# 1  1-dodecanol       NaN                1.0                0.0  Th(IV)
# 2  1-dodecanol       NaN                1.0                0.0  Th(IV)
# 3  1-dodecanol       NaN                1.0                0.0  Th(IV)
# 4  1-dodecanol       NaN                1.0                0.0  Th(IV)
#
#    Metal_conc_mM Acid_type  Acid_conc_M  Temperature_K  Distribution_ratio  \
# 0            1.0      HNO3          3.0         303.15            9.218341
# 1            1.0      HNO3          3.0         303.15            9.441048
# 2            1.0      HNO3          3.0         303.15           10.200873
# 3            1.0      HNO3          3.0         303.15           10.973799
# 4            1.0      HNO3          3.0         303.15           13.305677
#
#       Log_D                                        DOI  Comments
# 0  0.964653  https://doi.org/10.1007/s10967-017-5248-4  DGA LANL
# 1  0.975020  https://doi.org/10.1007/s10967-017-5248-4  DGA LANL
# 2  1.008637  https://doi.org/10.1007/s10967-017-5248-4  DGA LANL
# 3  1.040357  https://doi.org/10.1007/s10967-017-5248-4  DGA LANL
# 4  1.124037  https://doi.org/10.1007/s10967-017-5248-4  DGA LANL

# %%
all_refs_series = df['DOI'].drop_duplicates()
all_refs_series = all_refs_series.reset_index(drop=True)
all_refs_series.shape
# Out:
# (59,)

# %%
all_refs_series
# Out:
# 0             https://doi.org/10.1007/s10967-017-5248-4
# 1             https://doi.org/10.1007/s10967-017-5614-2
# 2        https://doi.org/10.1016/j.hydromet.2020.105248
# 3              https://doi.org/10.1021/acs.jpcb.6b11222
# 4                    https://doi.org/10.1039/C6DT04034A
# 5                    https://doi.org/10.1039/C7DT01954H
# 6            https://doi.org/10.1080/07366291003685383
# 7          https://doi.org/10.1080/07366299.2012.757160
# 8          https://doi.org/10.1080/07366299.2013.836422
