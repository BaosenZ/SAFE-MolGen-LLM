# %%
import pandas as pd

# %%
df = pd.read_excel("../../integrate_datasets_simple/output_integ_data.xlsx")
df.head()
# Out:
#    Entry_ID  Extractants_count                                        SMILES  \
# 0         0                  1  CN(C(=O)c1cccc(C(=O)N(C)c2ccccc2)n1)c1ccccc1
# 1         1                  1  CN(C(=O)c1cccc(C(=O)N(C)c2ccccc2)n1)c1ccccc1
# 2         2                  1  CN(C(=O)c1cccc(C(=O)N(C)c2ccccc2)n1)c1ccccc1
# 3         3                  1  CN(C(=O)c1cccc(C(=O)N(C)c2ccccc2)n1)c1ccccc1
# 4         4                  1  CN(C(=O)c1cccc(C(=O)N(C)c2ccccc2)n1)c1ccccc1
#
#    Extractant_conc_M Solvent_A Solvent_B  Volume_fraction_A  \
# 0                0.5     CH3Cl       NaN                1.0
# 1                0.5     CH3Cl       NaN                1.0
# 2                0.5     CH3Cl       NaN                1.0
# 3                0.5     CH3Cl       NaN                1.0
# 4                0.5     CH3Cl       NaN                1.0
#
#    Volume_fraction_B    Metal  Metal_conc_mM Acid_type  Acid_conc_M  \
# 0                0.0  La(III)           0.01      HNO3          1.0
# ...

# %%
all_acids_series = df['Acid_type'].drop_duplicates()
all_acids_series.shape
# Out:
# (4,)

# %%
all_acids_series.to_excel('output_unique_acids.xlsx', index=False)
