# %%
import pandas as pd

# %%
file_path = "../../prepare_LnDataset/output_integ_data.xlsx"
df = pd.read_excel(file_path)
df.head()
# Out:
#    Entry_ID  Extractants_count  \
# 0         0                  1
# 1         1                  1
# 2         2                  1
# 3         3                  1
# 4         4                  1
#
#                                               SMILES  Extractant_conc_M  \
# 0  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...                0.1
# 1  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...                0.1
# 2  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...                0.1
# 3  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...                0.1
# 4  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...                0.1
#
#                      Solvent_A Solvent_B  Volume_fraction_A  \
# 0  hydrogenated tetrapropylene       NaN                1.0
# 1  hydrogenated tetrapropylene       NaN                1.0
# 2  hydrogenated tetrapropylene       NaN                1.0
# 3  hydrogenated tetrapropylene       NaN                1.0
# ...

# %%
all_refs_series = df['DOI'].drop_duplicates()
all_refs_series = all_refs_series.reset_index(drop=True)
all_refs_series.shape
# Out:
# (87,)

# %%
all_refs_series
# Out:
# 0             https://doi.org/10.1002/chem.201806161
# 1                 https://doi.org/10.1007/BF02349516
# 2          https://doi.org/10.1007/s10967-017-5248-4
# 3         https://doi.org/10.1007/s10967-020-07242-1
# 4         https://doi.org/10.1007/s10967-020-07368-2
#                            ...
# 82      https://doi.org/10.1080/19443994.2012.664262
# 83      https://core.ac.uk/download/pdf/82226816.pdf
# 84    https://doi.org/10.1016/j.apradiso.2010.09.016
# 85         https://doi.org/10.1080/07360299908934599
# 86         https://doi.org/10.1080/07366299908934641
# Name: DOI, Length: 87, dtype: object

# %%
all_refs_series.to_excel('output_unique_refs.xlsx', index=True, index_label='Ref_ID')
