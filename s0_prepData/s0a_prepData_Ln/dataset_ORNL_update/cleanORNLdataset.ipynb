# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('original/full_original_dataset.xlsx')
print(df.shape)
df.head(3)
# Out:
# (1258, 44)
#    Entry ID  Ligand conc. (mM)  Volume ratio of solvent A  \
# 0         0              500.0                         10
# 1         1              500.0                         10
# 2         2              500.0                         10
#
#    Volume ratio of solvent B  Molar mass of solvent A  Density of solvent A  \
# 0                          0                    50.49                 1.003
# 1                          0                    50.49                 1.003
# 2                          0                    50.49                 1.003
#
#    Boiling point of solvent A  Melting point of solvent A  \
# 0                       249.3                       175.8
# 1                       249.3                       175.8
# 2                       249.3                       175.8
#
#    Dipole moment of solvent A  Solubility in water of solvent A  ...  \
# 0                         1.9                             5.325  ...
# 1                         1.9                             5.325  ...
# 2                         1.9                             5.325  ...
#
#    Ionic radius of metal  Standard entropy of metal (J/mol.K)     log D  \
# 0                   1.03                                 56.9  0.477121
# 1                   1.02                                 72.0  0.301030
# 2                   0.99                                 73.9  0.477121
#
#    Reference  train-val-test  Ligand ID  \
# 0          1           train    LigID_0
# 1          1           train    LigID_0
# 2          1           train    LigID_0
#
#                                        Ligand SMILES  Metal  Solvent A  \
# 0  CN(C(C1=CC=CC(C(N(C2=CC=CC=C2)C)=O)=N1)=O)C3=C...     La      CH3Cl
# 1  CN(C(C1=CC=CC(C(N(C2=CC=CC=C2)C)=O)=N1)=O)C3=C...     Ce      CH3Cl
# 2  CN(C(C1=CC=CC(C(N(C2=CC=CC=C2)C)=O)=N1)=O)C3=C...     Pr      CH3Cl
#
#    Solvent B
# 0        NaN
# 1        NaN
# 2        NaN
#
# [3 rows x 44 columns]

# %%
from rdkit import Chem

# %%
def get_canonical_smiles(smiles):
    molecule = Chem.MolFromSmiles(smiles)
    return Chem.MolToSmiles(molecule, canonical=True)

df['SMILES'] = df['Ligand SMILES'].apply(get_canonical_smiles)

# %%
# Convert ligand concentration
df['Ligand_conc_M'] = df['Ligand conc. (mM)']/1000

# %%
# Convert Temperature to Kelvin and create a new column 'Temperature_K'
df['Temperature_K'] = df['Temperature'] - 273 + 273.15

# %%
# Merge DOI

df_ref = pd.read_excel('original/full_original_dataset.xlsx', sheet_name = 'references')
df_ref.head(3)
# Out:
#    ID                                          Reference  \
# 0   1  A. Shimada, T. Yaita, H. Narita, S. Tachimori,...
# 1   2  M. R. Healy, A. S. Ivanov, Y. Karslyan, V. S. ...
# 2   3  E. Mowafy, D. Mohamed, Sep. Purif. Technol. 20...
#
#                                             DOI
# 0         https://doi.org/10.1081/SEI-120030392
# 1        https://doi.org/10.1002/chem.201806443
# 2  https://doi.org/10.1016/j.seppur.2014.03.005

# %%
# Sort by DOI ID
merged_df = pd.merge(df, df_ref, left_on='Reference', right_on='ID', how='left')

merged_df = merged_df.sort_values(by='ID')

# %%
# Merge acid type
acid_type_data = {
    'Acid_type': ['HNO3', 'HCl', 'H2SO4', 'Citric Acid', 'organic acid'],
    'Dipole_moment_D': [2.17, 1.05, 2.72, 3.33, 1.4]
}
acid_type_df = pd.DataFrame(acid_type_data)

merged_df = pd.merge(merged_df, acid_type_df, left_on='Acid dipole', right_on='Dipole_moment_D', how='left')

# %%
merged_df.head(3)
# Out:
#    Entry ID  Ligand conc. (mM)  Volume ratio of solvent A  \
# 0         0              500.0                         10
# 1        50              500.0                         10
# 2        49              500.0                         10
#
#    Volume ratio of solvent B  Molar mass of solvent A  Density of solvent A  \
# 0                          0                    50.49                 1.003
# 1                          0                    50.49                 1.003
# 2                          0                    50.49                 1.003
#
#    Boiling point of solvent A  Melting point of solvent A  \
# 0                       249.3                       175.8
# 1                       249.3                       175.8
# 2                       249.3                       175.8
#
#    Dipole moment of solvent A  Solubility in water of solvent A  ...  \
# 0                         1.9                             5.325  ...
# 1                         1.9                             5.325  ...
# 2                         1.9                             5.325  ...
#
#    Solvent A  Solvent B                                        SMILES  \
# 0      CH3Cl        NaN  CN(C(=O)c1cccc(C(=O)N(C)c2ccccc2)n1)c1ccccc1
# 1      CH3Cl        NaN  CN(C(=O)c1cccc(C(=O)N(C)c2ccccc2)n1)c1ccccc1
# 2      CH3Cl        NaN  CN(C(=O)c1cccc(C(=O)N(C)c2ccccc2)n1)c1ccccc1
#
#    Ligand_conc_M  Temperature_K  ID  \
# 0            0.5         273.15   1
# 1            0.5         273.15   1
# 2            0.5         273.15   1
#
#                                          Reference_y  \
# 0  A. Shimada, T. Yaita, H. Narita, S. Tachimori,...
# 1  A. Shimada, T. Yaita, H. Narita, S. Tachimori,...
# 2  A. Shimada, T. Yaita, H. Narita, S. Tachimori,...
#
#                                      DOI  Acid_type  Dipole_moment_D
# 0  https://doi.org/10.1081/SEI-120030392       HNO3             2.17
# 1  https://doi.org/10.1081/SEI-120030392       HNO3             2.17
# 2  https://doi.org/10.1081/SEI-120030392       HNO3             2.17
#
# [3 rows x 52 columns]

# %%
merged_df.to_excel('output_cleaned_data.xlsx', index=False)
