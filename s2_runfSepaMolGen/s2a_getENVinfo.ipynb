# %%
import platform
import numpy as np
import pandas as pd
import rdkit
import openai

print('platform information:', platform.platform())
print('processor information: ', platform.processor())
print("python version: ", platform.python_version())
print("np version: ", np.__version__)
print("pd version: ", pd.__version__)
print("rdkit version", rdkit.__version__)
print("openai version: ", openai.__version__)
# Out:
# platform information: Windows-10-10.0.26100-SP0
# processor information:  Intel64 Family 6 Model 186 Stepping 3, GenuineIntel
# python version:  3.11.7
# np version:  1.26.4
# pd version:  2.1.4
# rdkit version 2024.03.5
# openai version:  1.37.1
