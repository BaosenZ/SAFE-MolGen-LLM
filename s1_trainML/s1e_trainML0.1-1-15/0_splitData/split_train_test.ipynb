# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit

# %% [markdown]
# ## Split molecules (TrainVal, test)

# %%
df_unique_smiles_info = pd.read_excel("../../../s0_prepData/s0f_analyzeData_LnAn/output_uniqueSMILES_ClassBySMARTS.xlsx")
print(df_unique_smiles_info.shape)
df_unique_smiles_info.head(3)
# Out:
# (295, 4)
#    SMILES_ID                                             SMILES  \
# 0          0  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...
# 1          1  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@@H](C)C(=O...
# 2          2              CN(C(=O)COCC(=O)N(C)c1ccccc1)c1ccccc1
#
#                Class_by_SMARTS  \
# 0  Ether, Amide, Diglycolamide
# 1  Ether, Amide, Diglycolamide
# 2                 Ether, Amide
#
#                                           SMILES_DOI
# 0             https://doi.org/10.1002/chem.201806161
# 1             https://doi.org/10.1002/chem.201806161
# 2  https://doi.org/10.1007/BF02349516;https://doi...

# %%
class_counts = df_unique_smiles_info['Class_by_SMARTS'].value_counts()
class_counts
# Out:
# Class_by_SMARTS
# Amide                                                     65
# Ether, Amide, Diglycolamide                               62
# Ether, Amide                                              40
# Amide, Pyridine                                           32
# Pyridine                                                  23
# Other                                                     13
# Amide, Phosphine Oxides                                    9
# Phosphine Oxides                                           7
# Amide, Phosphine Oxides, Organophosphine Oxides            7
# Ether                                                      7
# Phosphine Oxides, Pyridine                                 5
# Ether, Amide, Pyridine                                     4
# Ether, Pyridine                                            4
# Ketone, Pyridine                                           3
# Hydroxyl, Phosphine Oxides                                 3
# Hydroxyl, Carboxylic Acid                                  2
# Ether, Amide, Phosphine Oxides                             2
# Hydroxyl, Carboxylic Acid, Amide                           1
# Hydroxyl                                                   1
# Hydroxyl, Carboxylic Acid, Pyridine                        1
# Ether, Amide, Phosphine Oxides, Organophosphine Oxides     1
# Phosphine Oxides, Organophosphine Oxides, Pyridine         1
# Ketone, Phosphine Oxides, Organophosphine Oxides           1
# Phosphine Oxides, Organophosphine Oxides                   1
# Name: count, dtype: int64

# %%
df_unique_smiles_info['Class_by_SMARTS_combineRare'] = df_unique_smiles_info['Class_by_SMARTS'].apply(lambda x: x if class_counts[x] > 3 else 'Rare groups')
print(df_unique_smiles_info.shape)
df_unique_smiles_info.head(3)
# Out:
# (295, 5)
#    SMILES_ID                                             SMILES  \
# 0          0  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...
# 1          1  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@@H](C)C(=O...
# 2          2              CN(C(=O)COCC(=O)N(C)c1ccccc1)c1ccccc1
#
#                Class_by_SMARTS  \
# 0  Ether, Amide, Diglycolamide
# 1  Ether, Amide, Diglycolamide
# 2                 Ether, Amide
#
#                                           SMILES_DOI  \
# 0             https://doi.org/10.1002/chem.201806161
# 1             https://doi.org/10.1002/chem.201806161
# 2  https://doi.org/10.1007/BF02349516;https://doi...
#
#    Class_by_SMARTS_combineRare
# 0  Ether, Amide, Diglycolamide
# 1  Ether, Amide, Diglycolamide
# 2                 Ether, Amide

# %%
class_counts_rareGroup = df_unique_smiles_info['Class_by_SMARTS_combineRare'].value_counts()
class_counts_rareGroup
# Out:
# Class_by_SMARTS_combineRare
# Amide                                              65
# Ether, Amide, Diglycolamide                        62
# Ether, Amide                                       40
# Amide, Pyridine                                    32
# Pyridine                                           23
# Rare groups                                        17
# Other                                              13
# Amide, Phosphine Oxides                             9
# Ether                                               7
# Amide, Phosphine Oxides, Organophosphine Oxides     7
# Phosphine Oxides                                    7
# Phosphine Oxides, Pyridine                          5
# Ether, Pyridine                                     4
# Ether, Amide, Pyridine                              4
# Name: count, dtype: int64

# %%
# Create the StratifiedShuffleSplit object
splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.05, random_state=0)

# Perform the split
for train_idx, test_idx in splitter.split(df_unique_smiles_info, df_unique_smiles_info['Class_by_SMARTS_combineRare']):
    train_set_SMILES = df_unique_smiles_info.loc[train_idx]
    test_set_SMILES = df_unique_smiles_info.loc[test_idx]

print(train_set_SMILES.shape)
print(test_set_SMILES.shape)
test_set_SMILES
# Out:
# (280, 5)
# (15, 5)
#      SMILES_ID                                             SMILES  \
# 175        175     CCCCC(CC)CP(=O)(CC(=O)N(CC(C)C)CC(C)C)c1ccccc1
# 35          35  CCCCCCCCN(CCCCCCCC)C(=O)COCC(=O)NCCNC(=O)c1cc(...
# 145        145                             CCCCCCCCNC(=O)c1cnccn1
# 133        133  CCCCC(CC)CN(CC(CC)CCCC)C(=O)CN(CC(=O)N(CC(CC)C...
# 243        243  CCCCN(CCCC)C(=O)COCC(=O)NCCCCCNC(=O)COCC(=O)N(...
# 53          53  CCCCCCCCCCCCN(CCC)C(=O)COCC(=O)N(CCC)CCCCCCCCCCCC
# 14          14                CCCCN(CCCC)C(=O)COCC(=O)N(CCCC)CCCC
# 169        169         CCCCCCCCN(CCCCCCCC)C(=O)COCP(=O)(CCCC)CCCC
# 228        228  CCCCNC(=S)C(CC)C(=S)Nc1cccc(NC(=S)C(CC)C(=S)NC...
# 63          63  CCN(C(=O)c1cccc(-c2cccc(C(=O)N(CC)c3cc(C)ccc3C...
# 162        162              CCCCOP(=S)(COCP(=S)(OCCCC)OCCCC)OCCCC
# 76          76  CCc1ccc(N(CC)C(=O)c2ccc3ccc4ccc(C(=O)N(CC)c5cc...
# 122        122  CC12CCC(c3nnc(-c4cccc(-c5cccc(-c6nnc7c(n6)C6(C...
# 90          90                    CCCCCCN(C)C(=O)CC(=O)N(C)CCCCCC
# 121        121  CCCCCCN(CCCC(C)CC(C)(C)C)C(=O)COCC(=O)N(CCCCCC...
#
#                                        Class_by_SMARTS  \
# 175                            Amide, Phosphine Oxides
# 35                                        Ether, Amide
# 145                                              Amide
# 133                                              Amide
# 243                                       Ether, Amide
# 53                         Ether, Amide, Diglycolamide
# 14                         Ether, Amide, Diglycolamide
# 169  Ether, Amide, Phosphine Oxides, Organophosphin...
# 228                                              Other
# 63                                     Amide, Pyridine
# 162                                              Ether
# 76                                     Amide, Pyridine
# 122                                           Pyridine
# 90                                               Amide
# 121                        Ether, Amide, Diglycolamide
#
#                                             SMILES_DOI  \
# 175          https://doi.org/10.1080/07366298608917877
# 35   https://doi.org/10.1039/C6DT04034A;https://doi...
# 145         https://cordis.europa.eu/project/id/211267
# 133         https://cordis.europa.eu/project/id/211267
# 243          https://doi.org/10.1080/07366290802672212
# 53               https://doi.org/10.2298/JSC171109043H
# 14   https://doi.org/10.1007/s41365-017-0229-4;http...
# 169         https://cordis.europa.eu/project/id/211267
# 228             https://doi.org/10.1524/ract.2008.1485
# 63                  https://doi.org/10.1039/C8DT03734E
# 162         https://cordis.europa.eu/project/id/211267
# 76                  https://doi.org/10.1039/C6RA08946A
# 122         https://cordis.europa.eu/project/id/211267
# 90           https://doi.org/10.1080/07366290600762322
# 121             https://doi.org/10.1021/jacsau.2c00122
#
#      Class_by_SMARTS_combineRare
# 175      Amide, Phosphine Oxides
# 35                  Ether, Amide
# 145                        Amide
# 133                        Amide
# 243                 Ether, Amide
# 53   Ether, Amide, Diglycolamide
# 14   Ether, Amide, Diglycolamide
# 169                  Rare groups
# 228                        Other
# 63               Amide, Pyridine
# 162                        Ether
# 76               Amide, Pyridine
# 122                     Pyridine
# 90                         Amide
# 121  Ether, Amide, Diglycolamide

# %%
test_set_SMILES['Class_by_SMARTS_combineRare'].value_counts()
# Out:
# Class_by_SMARTS_combineRare
# Amide                          3
# Ether, Amide, Diglycolamide    3
# Ether, Amide                   2
# Amide, Pyridine                2
# Amide, Phosphine Oxides        1
# Rare groups                    1
# Other                          1
# Ether                          1
# Pyridine                       1
# Name: count, dtype: int64

# %%
train_set_SMILES.to_excel('output_trainset_uniqueSMILES.xlsx', index=False)

# %% [markdown]
# ## Split entries

# %%
smiles_testDataset = test_set_SMILES['SMILES']
print(len(smiles_testDataset))
print(len(set(smiles_testDataset)))
# This two number should be the same
# Out:
# 15
# 15

# %%
df = pd.read_excel("../../../s0_prepData/s0e_prepData_LnAn/db_LnAn_full.xlsx", header=1)
print(df.shape)
df.head(3)
# Out:
# (8075, 17)
#    Entry_ID  Extractants_count  \
# 0         0                  1
# 1         1                  1
# 2         2                  1
#
#                                               SMILES  Extractant_conc_M  \
# 0  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...                0.1
# 1  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...                0.1
# 2  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...                0.1
#
#                      Solvent_A Solvent_B  Volume_fraction_A  \
# 0  hydrogenated tetrapropylene       NaN                1.0
# 1  hydrogenated tetrapropylene       NaN                1.0
# 2  hydrogenated tetrapropylene       NaN                1.0
#
#    Volume_fraction_B    Metal  Metal_conc_mM Acid_type  Acid_conc_M  \
# 0                0.0  La(III)           0.01      HNO3          4.3
# 1                0.0  Ce(III)           0.01      HNO3          4.3
# 2                0.0  Pr(III)           0.01      HNO3          4.3
#
#    Temperature_K  Distribution_ratio     Log_D  \
# 0         295.15            0.321764 -0.492462
# 1         295.15            0.622257 -0.206030
# 2         295.15            0.757525 -0.120603
#
#                                       DOI  Comments
# 0  https://doi.org/10.1002/chem.201806161  DGA LANL
# 1  https://doi.org/10.1002/chem.201806161  DGA LANL
# 2  https://doi.org/10.1002/chem.201806161  DGA LANL

# %%
def classify_D(x):
    if x < 0.1:
        class_index = 0
    elif x >= 0.1 and x < 1:
        class_index = 1
    elif x >= 1 and x < 15:
        class_index = 2
    else:
        class_index = 3
    return class_index

df['Class_index'] = df['Distribution_ratio'].apply(classify_D)
print(df.shape)
df.head()
# Out:
# (8075, 18)
#    Entry_ID  Extractants_count  \
# 0         0                  1
# 1         1                  1
# 2         2                  1
# 3         3                  1
# 4         4                  1
#
#                                               SMILES  Extractant_conc_M  \
# 0  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...                0.1
# 1  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...                0.1
# 2  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...                0.1
# 3  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...                0.1
# 4  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...                0.1
#
#                      Solvent_A Solvent_B  Volume_fraction_A  \
# 0  hydrogenated tetrapropylene       NaN                1.0
# 1  hydrogenated tetrapropylene       NaN                1.0
# 2  hydrogenated tetrapropylene       NaN                1.0
# 3  hydrogenated tetrapropylene       NaN                1.0
# 4  hydrogenated tetrapropylene       NaN                1.0
#
#    Volume_fraction_B    Metal  Metal_conc_mM Acid_type  Acid_conc_M  \
# 0                0.0  La(III)           0.01      HNO3          4.3
# 1                0.0  Ce(III)           0.01      HNO3          4.3
# 2                0.0  Pr(III)           0.01      HNO3          4.3
# 3                0.0  Nd(III)           0.01      HNO3          4.3
# 4                0.0  Sm(III)           0.01      HNO3          4.3
#
#    Temperature_K  Distribution_ratio     Log_D  \
# 0         295.15            0.321764 -0.492462
# 1         295.15            0.622257 -0.206030
# 2         295.15            0.757525 -0.120603
# 3         295.15            0.775260 -0.110553
# 4         295.15            0.830994 -0.080402
#
#                                       DOI  Comments  Class_index
# 0  https://doi.org/10.1002/chem.201806161  DGA LANL            1
# 1  https://doi.org/10.1002/chem.201806161  DGA LANL            1
# 2  https://doi.org/10.1002/chem.201806161  DGA LANL            1
# 3  https://doi.org/10.1002/chem.201806161  DGA LANL            1
# 4  https://doi.org/10.1002/chem.201806161  DGA LANL            1

# %%
df['Class_index'].value_counts().sort_index()
# Out:
# Class_index
# 0    1967
# 1    1753
# 2    2456
# 3    1899
# Name: count, dtype: int64

# %%
def classify_smiles(smiles):
    smiles_class = df_unique_smiles_info[df_unique_smiles_info['SMILES'] == smiles]
    
    return smiles_class['Class_by_SMARTS_combineRare'].values[0]

df['SMILES_class'] = df['SMILES'].apply(classify_smiles)
print(df.shape)
df.head(3)
# Out:
# (8075, 19)
#    Entry_ID  Extractants_count  \
# 0         0                  1
# 1         1                  1
# 2         2                  1
#
#                                               SMILES  Extractant_conc_M  \
# 0  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...                0.1
# 1  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...                0.1
# 2  CCCCCCCCN(CCCCCCCC)C(=O)[C@H](C)O[C@H](C)C(=O)...                0.1
#
#                      Solvent_A Solvent_B  Volume_fraction_A  \
# 0  hydrogenated tetrapropylene       NaN                1.0
# 1  hydrogenated tetrapropylene       NaN                1.0
# 2  hydrogenated tetrapropylene       NaN                1.0
#
#    Volume_fraction_B    Metal  Metal_conc_mM Acid_type  Acid_conc_M  \
# 0                0.0  La(III)           0.01      HNO3          4.3
# 1                0.0  Ce(III)           0.01      HNO3          4.3
# 2                0.0  Pr(III)           0.01      HNO3          4.3
#
#    Temperature_K  Distribution_ratio     Log_D  \
# 0         295.15            0.321764 -0.492462
# 1         295.15            0.622257 -0.206030
# 2         295.15            0.757525 -0.120603
#
#                                       DOI  Comments  Class_index  \
# 0  https://doi.org/10.1002/chem.201806161  DGA LANL            1
# 1  https://doi.org/10.1002/chem.201806161  DGA LANL            1
# 2  https://doi.org/10.1002/chem.201806161  DGA LANL            1
#
#                   SMILES_class
# 0  Ether, Amide, Diglycolamide
# 1  Ether, Amide, Diglycolamide
# 2  Ether, Amide, Diglycolamide

# %%
trainValDataset_df = df[~df['SMILES'].isin(smiles_testDataset)]
testDataset_df = df[df['SMILES'].isin(smiles_testDataset)]
print(trainValDataset_df.shape)
print(testDataset_df.shape)
# Out:
# (7581, 19)
# (494, 19)

# %%
testDataset_df['Class_index'].value_counts().sort_index()
# Out:
# Class_index
# 0     82
# 1    134
# 2    211
# 3     67
# Name: count, dtype: int64

# %%
output_file = "output_original_MLdataset.xlsx"
with pd.ExcelWriter(output_file) as writer:
    trainValDataset_df.to_excel(writer, sheet_name='trainVal_dataset', index=False)
    testDataset_df.to_excel(writer, sheet_name='test_dataset', index=False)
